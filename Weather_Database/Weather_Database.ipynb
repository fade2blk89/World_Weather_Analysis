# %%
# Import the requests library and dependencies.
import requests
import numpy as np
from citipy import citipy

# Import the API key.
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Using the citipy module, identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 733

# %%
#Base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
import time
weather_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(10)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_descript = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        weather_data.append({"City": city.title(),
                             "Country": city_country,
                             "Lat": city_lat,
                             "Lng": city_lng,
                             "Max Temp": city_max_temp,
                             "Humidity": city_humidity,
                             "Cloudiness": city_clouds,
                             "Wind Speed": city_wind,
                             "Current Description": city_descript})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | kavieng
# Processing Record 2 of Set 1 | whitehorse
# Processing Record 3 of Set 1 | atar
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | lorengau
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | itarema
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | laguna
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | tuktoyaktuk
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | nikolskoye
# Processing Record 17 of Set 1 | chokurdakh
# Processing Record 18 of Set 1 | maumere
# Processing Record 19 of Set 1 | barra do garcas
# Processing Record 20 of Set 1 | cayenne
# Processing Record 21 of Set 1 | tessalit
# Processing Record 22 of Set 1 | canaries
# Processing Record 23 of Set 1 | vaini
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 1 | charters towers
# Processing Record 27 of Set 1 | stratford-upon-avon
# Processing Record 28 of Set 1 | la ronge
# Processing Record 29 of Set 1 | bac lieu
# Processing Record 30 of Set 1 | capim grosso
# Processing Record 31 of Set 1 | kalmunai
# Processing Record 32 of Set 1 | sairang
# Processing Record 33 of Set 1 | cape town
# Processing Record 34 of Set 1 | hovd
# Processing Record 35 of Set 1 | port-gentil
# Processing Record 36 of Set 1 | lebu
# Processing Record 37 of Set 1 | saskylakh
# Processing Record 38 of Set 1 | sabang
# Processing Record 39 of Set 1 | maltahohe
# Processing Record 40 of Set 1 | tigil
# Processing Record 41 of Set 1 | port alfred
# Processing Record 42 of Set 1 | leningradskiy
# Processing Record 43 of Set 1 | thompson
# Processing Record 44 of Set 1 | tambopata
# Processing Record 45 of Set 1 | abonnema
# Processing Record 46 of Set 1 | los altos
# Processing Record 47 of Set 1 | launceston
# Processing Record 48 of Set 1 | birobidzhan
# Processing Record 49 of Set 1 | felipe carrillo puerto
# Processing Record 50 of Set 1 | mindelo
# Processing Record 1 of Set 2 | saint-joseph
# Processing Record 2 of Set 2 | pevek
# Processing Record 3 of Set 2 | arenys de mar
# Processing Record 4 of Set 2 | isangel
# Processing Record 5 of Set 2 | geraldton
# Processing Record 6 of Set 2 | port hardy
# Processing Record 7 of Set 2 | broken hill
# Processing Record 8 of Set 2 | upernavik
# Processing Record 9 of Set 2 | san ignacio
# Processing Record 10 of Set 2 | ternate
# Processing Record 11 of Set 2 | kushmurun
# Processing Record 12 of Set 2 | ligayan
# Processing Record 13 of Set 2 | qaanaaq
# Processing Record 14 of Set 2 | polonnaruwa
# Processing Record 15 of Set 2 | cedar city
# Processing Record 16 of Set 2 | saint-augustin
# Processing Record 17 of Set 2 | buraydah
# Processing Record 18 of Set 2 | galiwinku
# City not found. Skipping...
# Processing Record 19 of Set 2 | avarua
# Processing Record 20 of Set 2 | torbay
# Processing Record 21 of Set 2 | aripuana
# Processing Record 22 of Set 2 | saint-philippe
# Processing Record 23 of Set 2 | talara
# Processing Record 24 of Set 2 | cidreira
# Processing Record 25 of Set 2 | bluff
# Processing Record 26 of Set 2 | west plains
# Processing Record 27 of Set 2 | kahului
# Processing Record 28 of Set 2 | inirida
# Processing Record 29 of Set 2 | chuy
# Processing Record 30 of Set 2 | sao joao da barra
# Processing Record 31 of Set 2 | yerbogachen
# Processing Record 32 of Set 2 | hithadhoo
# Processing Record 33 of Set 2 | bethel
# Processing Record 34 of Set 2 | namatanai
# Processing Record 35 of Set 2 | cherskiy
# Processing Record 36 of Set 2 | atbasar
# Processing Record 37 of Set 2 | aklavik
# Processing Record 38 of Set 2 | longonjo
# Processing Record 39 of Set 2 | sobolevo
# Processing Record 40 of Set 2 | stokmarknes
# Processing Record 41 of Set 2 | moroni
# Processing Record 42 of Set 2 | tecoanapa
# Processing Record 43 of Set 2 | aloleng
# Processing Record 44 of Set 2 | hermanus
# Processing Record 45 of Set 2 | dingle
# Processing Record 46 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 47 of Set 2 | salalah
# Processing Record 48 of Set 2 | shasta lake
# Processing Record 49 of Set 2 | castres
# Processing Record 50 of Set 2 | castro
# Processing Record 1 of Set 3 | wichita falls
# Processing Record 2 of Set 3 | cabedelo
# Processing Record 3 of Set 3 | aguimes
# Processing Record 4 of Set 3 | samarai
# Processing Record 5 of Set 3 | brae
# Processing Record 6 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 3 | ancud
# Processing Record 8 of Set 3 | faya
# Processing Record 9 of Set 3 | saint joseph
# Processing Record 10 of Set 3 | yellowknife
# Processing Record 11 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 12 of Set 3 | lavrentiya
# Processing Record 13 of Set 3 | east london
# Processing Record 14 of Set 3 | kaitangata
# Processing Record 15 of Set 3 | bengkulu
# Processing Record 16 of Set 3 | butaritari
# Processing Record 17 of Set 3 | shangqiu
# Processing Record 18 of Set 3 | hilo
# Processing Record 19 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 20 of Set 3 | poso
# Processing Record 21 of Set 3 | qui nhon
# Processing Record 22 of Set 3 | paciran
# Processing Record 23 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 3 | cabo san lucas
# Processing Record 25 of Set 3 | masunga
# Processing Record 26 of Set 3 | shihezi
# Processing Record 27 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 3 | adrar
# Processing Record 29 of Set 3 | kamenka
# Processing Record 30 of Set 3 | palmer
# Processing Record 31 of Set 3 | severo-kurilsk
# Processing Record 32 of Set 3 | kampene
# Processing Record 33 of Set 3 | touros
# Processing Record 34 of Set 3 | kapaa
# Processing Record 35 of Set 3 | yulara
# Processing Record 36 of Set 3 | tasiilaq
# Processing Record 37 of Set 3 | vila franca do campo
# Processing Record 38 of Set 3 | carnarvon
# Processing Record 39 of Set 3 | imeni poliny osipenko
# Processing Record 40 of Set 3 | ust-tsilma
# Processing Record 41 of Set 3 | borlange
# City not found. Skipping...
# Processing Record 42 of Set 3 | ribeira brava
# Processing Record 43 of Set 3 | te anau
# Processing Record 44 of Set 3 | changji
# Processing Record 45 of Set 3 | bredasdorp
# Processing Record 46 of Set 3 | bubaque
# Processing Record 47 of Set 3 | kokoda
# Processing Record 48 of Set 3 | tulle
# Processing Record 49 of Set 3 | homer
# Processing Record 50 of Set 3 | airai
# Processing Record 1 of Set 4 | mount isa
# Processing Record 2 of Set 4 | clyde river
# Processing Record 3 of Set 4 | mehamn
# Processing Record 4 of Set 4 | puerto del rosario
# Processing Record 5 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 6 of Set 4 | sinnamary
# Processing Record 7 of Set 4 | natitingou
# Processing Record 8 of Set 4 | avera
# Processing Record 9 of Set 4 | georgetown
# Processing Record 10 of Set 4 | mnogovershinnyy
# Processing Record 11 of Set 4 | mar del plata
# Processing Record 12 of Set 4 | chigorodo
# Processing Record 13 of Set 4 | palu
# Processing Record 14 of Set 4 | alamogordo
# Processing Record 15 of Set 4 | ponta delgada
# Processing Record 16 of Set 4 | fortuna
# Processing Record 17 of Set 4 | hirara
# Processing Record 18 of Set 4 | de-kastri
# Processing Record 19 of Set 4 | hasaki
# Processing Record 20 of Set 4 | nueve de julio
# Processing Record 21 of Set 4 | mbouda
# Processing Record 22 of Set 4 | tawkar
# City not found. Skipping...
# Processing Record 23 of Set 4 | kodiak
# Processing Record 24 of Set 4 | bundaberg
# Processing Record 25 of Set 4 | forestville
# Processing Record 26 of Set 4 | santa isabel do rio negro
# Processing Record 27 of Set 4 | skibbereen
# Processing Record 28 of Set 4 | carutapera
# Processing Record 29 of Set 4 | lensk
# Processing Record 30 of Set 4 | karakendzha
# City not found. Skipping...
# Processing Record 31 of Set 4 | ubajara
# Processing Record 32 of Set 4 | ardakan
# Processing Record 33 of Set 4 | gadung
# Processing Record 34 of Set 4 | tangping
# Processing Record 35 of Set 4 | san carlos de bariloche
# Processing Record 36 of Set 4 | saldanha
# Processing Record 37 of Set 4 | san patricio
# Processing Record 38 of Set 4 | dien bien
# City not found. Skipping...
# Processing Record 39 of Set 4 | tagusao
# Processing Record 40 of Set 4 | port elizabeth
# Processing Record 41 of Set 4 | nadym
# Processing Record 42 of Set 4 | asosa
# Processing Record 43 of Set 4 | souillac
# Processing Record 44 of Set 4 | nioro
# Processing Record 45 of Set 4 | pangnirtung
# Processing Record 46 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 4 | kahramanmaras
# Processing Record 48 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 4 | tosya
# Processing Record 50 of Set 4 | bambous virieux
# Processing Record 1 of Set 5 | klaksvik
# Processing Record 2 of Set 5 | kruisfontein
# Processing Record 3 of Set 5 | ixtapa
# Processing Record 4 of Set 5 | tonshayevo
# Processing Record 5 of Set 5 | luderitz
# Processing Record 6 of Set 5 | cockburn town
# Processing Record 7 of Set 5 | ludvika
# Processing Record 8 of Set 5 | vao
# Processing Record 9 of Set 5 | nyurba
# Processing Record 10 of Set 5 | zaragoza
# Processing Record 11 of Set 5 | hundorp
# Processing Record 12 of Set 5 | araguacu
# Processing Record 13 of Set 5 | katobu
# Processing Record 14 of Set 5 | jiaozuo
# Processing Record 15 of Set 5 | den helder
# Processing Record 16 of Set 5 | namibe
# Processing Record 17 of Set 5 | khatanga
# Processing Record 18 of Set 5 | hobart
# Processing Record 19 of Set 5 | andenes
# Processing Record 20 of Set 5 | ahumada
# City not found. Skipping...
# Processing Record 21 of Set 5 | rawson
# Processing Record 22 of Set 5 | dubovka
# Processing Record 23 of Set 5 | new norfolk
# Processing Record 24 of Set 5 | jumla
# Processing Record 25 of Set 5 | olafsvik
# Processing Record 26 of Set 5 | ahuimanu
# Processing Record 27 of Set 5 | toftir
# City not found. Skipping...
# Processing Record 28 of Set 5 | paamiut
# Processing Record 29 of Set 5 | hare bay
# Processing Record 30 of Set 5 | juan lacaze
# Processing Record 31 of Set 5 | alofi
# Processing Record 32 of Set 5 | kiama
# Processing Record 33 of Set 5 | espanola
# Processing Record 34 of Set 5 | isperih
# Processing Record 35 of Set 5 | sun prairie
# Processing Record 36 of Set 5 | sao felix do xingu
# Processing Record 37 of Set 5 | akdepe
# Processing Record 38 of Set 5 | codrington
# Processing Record 39 of Set 5 | nanortalik
# Processing Record 40 of Set 5 | turukhansk
# Processing Record 41 of Set 5 | emerald
# Processing Record 42 of Set 5 | yumen
# Processing Record 43 of Set 5 | saint-pierre
# Processing Record 44 of Set 5 | wanning
# Processing Record 45 of Set 5 | san andres
# Processing Record 46 of Set 5 | ossora
# Processing Record 47 of Set 5 | qiongshan
# Processing Record 48 of Set 5 | aljezur
# Processing Record 49 of Set 5 | mareeba
# Processing Record 50 of Set 5 | hearst
# Processing Record 1 of Set 6 | puerto escondido
# Processing Record 2 of Set 6 | raudeberg
# Processing Record 3 of Set 6 | longyearbyen
# Processing Record 4 of Set 6 | colares
# Processing Record 5 of Set 6 | tazovskiy
# Processing Record 6 of Set 6 | alyangula
# Processing Record 7 of Set 6 | hami
# Processing Record 8 of Set 6 | amapa
# Processing Record 9 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 6 | havoysund
# Processing Record 11 of Set 6 | saint george
# Processing Record 12 of Set 6 | mouzakion
# City not found. Skipping...
# Processing Record 13 of Set 6 | natchitoches
# Processing Record 14 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 16 of Set 6 | nome
# Processing Record 17 of Set 6 | grand gaube
# Processing Record 18 of Set 6 | slavyanka
# Processing Record 19 of Set 6 | melfort
# Processing Record 20 of Set 6 | xining
# Processing Record 21 of Set 6 | erenhot
# Processing Record 22 of Set 6 | aswan
# Processing Record 23 of Set 6 | wanaka
# Processing Record 24 of Set 6 | ponta do sol
# Processing Record 25 of Set 6 | hamilton
# Processing Record 26 of Set 6 | georgiyevka
# Processing Record 27 of Set 6 | taburi
# City not found. Skipping...
# Processing Record 28 of Set 6 | tobati
# Processing Record 29 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 30 of Set 6 | arroyo
# Processing Record 31 of Set 6 | half moon bay
# Processing Record 32 of Set 6 | mayumba
# Processing Record 33 of Set 6 | ribeira grande
# Processing Record 34 of Set 6 | barrow
# Processing Record 35 of Set 6 | barentu
# Processing Record 36 of Set 6 | arraial do cabo
# Processing Record 37 of Set 6 | zhuhai
# Processing Record 38 of Set 6 | kathmandu
# Processing Record 39 of Set 6 | astoria
# Processing Record 40 of Set 6 | mambajao
# Processing Record 41 of Set 6 | ibra
# Processing Record 42 of Set 6 | zyryanka
# Processing Record 43 of Set 6 | banyo
# Processing Record 44 of Set 6 | vardo
# Processing Record 45 of Set 6 | dawlatabad
# Processing Record 46 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 47 of Set 6 | port hawkesbury
# Processing Record 48 of Set 6 | dikson
# Processing Record 49 of Set 6 | pirajui
# Processing Record 50 of Set 6 | beyneu
# Processing Record 1 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 7 | sakakah
# Processing Record 3 of Set 7 | san miguel
# Processing Record 4 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 6 of Set 7 | cururupu
# Processing Record 7 of Set 7 | azuaga
# Processing Record 8 of Set 7 | higuey
# City not found. Skipping...
# Processing Record 9 of Set 7 | mushie
# Processing Record 10 of Set 7 | fare
# Processing Record 11 of Set 7 | inuvik
# Processing Record 12 of Set 7 | lixourion
# Processing Record 13 of Set 7 | sola
# Processing Record 14 of Set 7 | muros
# Processing Record 15 of Set 7 | havre-saint-pierre
# Processing Record 16 of Set 7 | ferme-neuve
# Processing Record 17 of Set 7 | nishihara
# Processing Record 18 of Set 7 | mbaiki
# Processing Record 19 of Set 7 | esperance
# Processing Record 20 of Set 7 | tuatapere
# Processing Record 21 of Set 7 | kokstad
# Processing Record 22 of Set 7 | dzilam gonzalez
# Processing Record 23 of Set 7 | katra
# Processing Record 24 of Set 7 | tsiroanomandidy
# Processing Record 25 of Set 7 | baherden
# Processing Record 26 of Set 7 | zevio
# Processing Record 27 of Set 7 | oktyabrskiy
# Processing Record 28 of Set 7 | port hedland
# Processing Record 29 of Set 7 | kontagora
# Processing Record 30 of Set 7 | nurota
# Processing Record 31 of Set 7 | henties bay
# Processing Record 32 of Set 7 | ciudad bolivar
# Processing Record 33 of Set 7 | porirua
# Processing Record 34 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 35 of Set 7 | merauke
# Processing Record 36 of Set 7 | lufilufi
# Processing Record 37 of Set 7 | joensuu
# Processing Record 38 of Set 7 | fairbanks
# Processing Record 39 of Set 7 | uk
# City not found. Skipping...
# Processing Record 40 of Set 7 | bardiyah
# Processing Record 41 of Set 7 | celestun
# Processing Record 42 of Set 7 | savinka
# Processing Record 43 of Set 7 | eydhafushi
# Processing Record 44 of Set 7 | tinyahuarco
# Processing Record 45 of Set 7 | wanganui
# Processing Record 46 of Set 7 | teguldet
# Processing Record 47 of Set 7 | samagaltay
# Processing Record 48 of Set 7 | muyezerskiy
# Processing Record 49 of Set 7 | wai
# Processing Record 50 of Set 7 | sao sepe
# Processing Record 1 of Set 8 | araruama
# Processing Record 2 of Set 8 | rabaul
# Processing Record 3 of Set 8 | livramento
# Processing Record 4 of Set 8 | brigantine
# Processing Record 5 of Set 8 | nizhniy kuranakh
# Processing Record 6 of Set 8 | tshane
# Processing Record 7 of Set 8 | portland
# Processing Record 8 of Set 8 | irondequoit
# Processing Record 9 of Set 8 | santa cruz de tenerife
# Processing Record 10 of Set 8 | bay roberts
# Processing Record 11 of Set 8 | macapa
# Processing Record 12 of Set 8 | mount gambier
# Processing Record 13 of Set 8 | rantoul
# Processing Record 14 of Set 8 | tilichiki
# Processing Record 15 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 16 of Set 8 | kodinsk
# Processing Record 17 of Set 8 | barkly west
# Processing Record 18 of Set 8 | ouegoa
# Processing Record 19 of Set 8 | beringovskiy
# Processing Record 20 of Set 8 | kharagpur
# Processing Record 21 of Set 8 | velyka kisnytsya
# City not found. Skipping...
# Processing Record 22 of Set 8 | parras
# City not found. Skipping...
# Processing Record 23 of Set 8 | tiksi
# Processing Record 24 of Set 8 | lapa
# Processing Record 25 of Set 8 | sao jose da coroa grande
# Processing Record 26 of Set 8 | catanduva
# Processing Record 27 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 28 of Set 8 | kulunda
# Processing Record 29 of Set 8 | rumoi
# Processing Record 30 of Set 8 | nouakchott
# Processing Record 31 of Set 8 | taltal
# Processing Record 32 of Set 8 | hurghada
# Processing Record 33 of Set 8 | rio gallegos
# Processing Record 34 of Set 8 | abu samrah
# Processing Record 35 of Set 8 | iqaluit
# Processing Record 36 of Set 8 | asau
# Processing Record 37 of Set 8 | larap
# Processing Record 38 of Set 8 | norman wells
# Processing Record 39 of Set 8 | ilulissat
# Processing Record 40 of Set 8 | muroto
# Processing Record 41 of Set 8 | high prairie
# Processing Record 42 of Set 8 | abha
# Processing Record 43 of Set 8 | tautira
# Processing Record 44 of Set 8 | glen allen
# Processing Record 45 of Set 8 | sao filipe
# Processing Record 46 of Set 8 | riyadh
# Processing Record 47 of Set 8 | novobirilyussy
# Processing Record 48 of Set 8 | wufeng
# Processing Record 49 of Set 8 | bossembele
# City not found. Skipping...
# Processing Record 50 of Set 8 | split
# Processing Record 1 of Set 9 | road town
# Processing Record 2 of Set 9 | broome
# Processing Record 3 of Set 9 | benjamin hill
# Processing Record 4 of Set 9 | syracuse
# Processing Record 5 of Set 9 | vila velha
# Processing Record 6 of Set 9 | cestas
# Processing Record 7 of Set 9 | valparaiso
# Processing Record 8 of Set 9 | kirakira
# Processing Record 9 of Set 9 | talnakh
# Processing Record 10 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 9 | bilibino
# Processing Record 12 of Set 9 | jabiru
# City not found. Skipping...
# Processing Record 13 of Set 9 | seymchan
# Processing Record 14 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 9 | burica
# City not found. Skipping...
# Processing Record 16 of Set 9 | fredericton
# Processing Record 17 of Set 9 | panjab
# Processing Record 18 of Set 9 | cap malheureux
# Processing Record 19 of Set 9 | margate
# Processing Record 20 of Set 9 | palmas
# Processing Record 21 of Set 9 | general roca
# Processing Record 22 of Set 9 | veshenskaya
# Processing Record 23 of Set 9 | ahipara
# Processing Record 24 of Set 9 | kemijarvi
# Processing Record 25 of Set 9 | kieta
# Processing Record 26 of Set 9 | la cruz
# Processing Record 27 of Set 9 | makakilo city
# Processing Record 28 of Set 9 | richards bay
# Processing Record 29 of Set 9 | narsaq
# Processing Record 30 of Set 9 | gorontalo
# Processing Record 31 of Set 9 | fort nelson
# Processing Record 32 of Set 9 | cascais
# Processing Record 33 of Set 9 | lazaro cardenas
# Processing Record 34 of Set 9 | szabadbattyan
# Processing Record 35 of Set 9 | ginir
# Processing Record 36 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 37 of Set 9 | san anselmo
# Processing Record 38 of Set 9 | kathu
# Processing Record 39 of Set 9 | kolvereid
# Processing Record 40 of Set 9 | ust-ilimsk
# Processing Record 41 of Set 9 | alice springs
# Processing Record 42 of Set 9 | inhambane
# Processing Record 43 of Set 9 | moindou
# Processing Record 44 of Set 9 | toowoomba
# Processing Record 45 of Set 9 | pisco
# Processing Record 46 of Set 9 | beruwala
# Processing Record 47 of Set 9 | ketchenery
# City not found. Skipping...
# Processing Record 48 of Set 9 | banda aceh
# Processing Record 49 of Set 9 | nador
# Processing Record 50 of Set 9 | iranshahr
# Processing Record 1 of Set 10 | sinkat
# City not found. Skipping...
# Processing Record 2 of Set 10 | murupara
# Processing Record 3 of Set 10 | bababe
# City not found. Skipping...
# Processing Record 4 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 10 | carbondale
# Processing Record 6 of Set 10 | faanui
# Processing Record 7 of Set 10 | hervey bay
# Processing Record 8 of Set 10 | juazeirinho
# Processing Record 9 of Set 10 | akyab
# Processing Record 10 of Set 10 | camacha
# Processing Record 11 of Set 10 | coihaique
# Processing Record 12 of Set 10 | lasa
# Processing Record 13 of Set 10 | bathsheba
# Processing Record 14 of Set 10 | cockburn harbour
# City not found. Skipping...
# Processing Record 15 of Set 10 | burns lake
# Processing Record 16 of Set 10 | pathein
# Processing Record 17 of Set 10 | shakawe
# Processing Record 18 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 19 of Set 10 | channel-port aux basques
# Processing Record 20 of Set 10 | gangotri
# City not found. Skipping...
# Processing Record 21 of Set 10 | campos sales
# Processing Record 22 of Set 10 | nouadhibou
# Processing Record 23 of Set 10 | plettenberg bay
# Processing Record 24 of Set 10 | waddan
# Processing Record 25 of Set 10 | narrabri
# Processing Record 26 of Set 10 | pontes e lacerda
# Processing Record 27 of Set 10 | naze
# Processing Record 28 of Set 10 | moree
# Processing Record 29 of Set 10 | formoso do araguaia
# City not found. Skipping...
# Processing Record 30 of Set 10 | greenwood
# Processing Record 31 of Set 10 | aykhal
# Processing Record 32 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 10 | jalu
# Processing Record 34 of Set 10 | victoria
# Processing Record 35 of Set 10 | preobrazheniye
# Processing Record 36 of Set 10 | siverek
# Processing Record 37 of Set 10 | saint-georges
# Processing Record 38 of Set 10 | provideniya
# Processing Record 39 of Set 10 | deputatskiy
# Processing Record 40 of Set 10 | ostrovnoy
# Processing Record 41 of Set 10 | jenjarom
# Processing Record 42 of Set 10 | pandan
# Processing Record 43 of Set 10 | marsh harbour
# Processing Record 44 of Set 10 | loukhi
# Processing Record 45 of Set 10 | grindavik
# Processing Record 46 of Set 10 | chapais
# Processing Record 47 of Set 10 | balykshi
# Processing Record 48 of Set 10 | mananjary
# Processing Record 49 of Set 10 | tornio
# Processing Record 50 of Set 10 | lumphat
# Processing Record 1 of Set 11 | vallenar
# Processing Record 2 of Set 11 | dire
# Processing Record 3 of Set 11 | lerwick
# Processing Record 4 of Set 11 | boende
# Processing Record 5 of Set 11 | guerrero negro
# Processing Record 6 of Set 11 | cobija
# Processing Record 7 of Set 11 | san-pedro
# Processing Record 8 of Set 11 | udachnyy
# Processing Record 9 of Set 11 | natal
# Processing Record 10 of Set 11 | palmares do sul
# Processing Record 11 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 12 of Set 11 | algete
# Processing Record 13 of Set 11 | marawi
# Processing Record 14 of Set 11 | mandera
# Processing Record 15 of Set 11 | surdulica
# Processing Record 16 of Set 11 | berlevag
# Processing Record 17 of Set 11 | mendeleyevo
# Processing Record 18 of Set 11 | lompoc
# Processing Record 19 of Set 11 | feni
# Processing Record 20 of Set 11 | ola
# Processing Record 21 of Set 11 | edmond
# Processing Record 22 of Set 11 | bara
# Processing Record 23 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 24 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 11 | hit
# Processing Record 26 of Set 11 | lichinga
# Processing Record 27 of Set 11 | almaznyy
# Processing Record 28 of Set 11 | nago
# Processing Record 29 of Set 11 | katsuura
# Processing Record 30 of Set 11 | balvi
# Processing Record 31 of Set 11 | artyom
# Processing Record 32 of Set 11 | vanavara
# Processing Record 33 of Set 11 | springfield
# Processing Record 34 of Set 11 | kopychyntsi
# Processing Record 35 of Set 11 | bako
# Processing Record 36 of Set 11 | tara
# Processing Record 37 of Set 11 | zhigansk
# Processing Record 38 of Set 11 | port macquarie
# Processing Record 39 of Set 11 | moundsville
# Processing Record 40 of Set 11 | lufkin
# Processing Record 41 of Set 11 | we
# City not found. Skipping...
# Processing Record 42 of Set 11 | ust-nera
# Processing Record 43 of Set 11 | batagay-alyta
# Processing Record 44 of Set 11 | odweyne
# Processing Record 45 of Set 11 | ninh binh
# Processing Record 46 of Set 11 | takaka
# Processing Record 47 of Set 11 | xuddur
# Processing Record 48 of Set 11 | sioux lookout
# Processing Record 49 of Set 11 | port lincoln
# Processing Record 50 of Set 11 | buluang
# Processing Record 1 of Set 12 | phuket
# Processing Record 2 of Set 12 | kamaishi
# Processing Record 3 of Set 12 | santa maria
# Processing Record 4 of Set 12 | dandong
# Processing Record 5 of Set 12 | killybegs
# Processing Record 6 of Set 12 | izumo
# Processing Record 7 of Set 12 | boa vista
# Processing Record 8 of Set 12 | tonantins
# Processing Record 9 of Set 12 | neya
# Processing Record 10 of Set 12 | porosozero
# Processing Record 11 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 12 of Set 12 | svetlogorsk
# Processing Record 13 of Set 12 | pedernales
# Processing Record 14 of Set 12 | walvis bay
# Processing Record 15 of Set 12 | ishigaki
# Processing Record 16 of Set 12 | nokaneng
# Processing Record 17 of Set 12 | morgan city
# Processing Record 18 of Set 12 | mbini
# Processing Record 19 of Set 12 | conselheiro lafaiete
# Processing Record 20 of Set 12 | hoi an
# Processing Record 21 of Set 12 | okitipupa
# Processing Record 22 of Set 12 | mahebourg
# Processing Record 23 of Set 12 | lukulu
# Processing Record 24 of Set 12 | umm lajj
# Processing Record 25 of Set 12 | emba
# Processing Record 26 of Set 12 | finschhafen
# Processing Record 27 of Set 12 | picos
# Processing Record 28 of Set 12 | roald
# Processing Record 29 of Set 12 | qorveh
# Processing Record 30 of Set 12 | goulburn
# Processing Record 31 of Set 12 | padang
# Processing Record 32 of Set 12 | mana
# Processing Record 33 of Set 12 | sunland park
# Processing Record 34 of Set 12 | sumbe
# Processing Record 35 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 36 of Set 12 | karratha
# Processing Record 37 of Set 12 | onda
# Processing Record 38 of Set 12 | borogontsy
# Processing Record 39 of Set 12 | lakes entrance
# Processing Record 40 of Set 12 | aksakovo
# Processing Record 41 of Set 12 | johi
# Processing Record 42 of Set 12 | missoula
# Processing Record 43 of Set 12 | bonavista
# Processing Record 44 of Set 12 | lao cai
# Processing Record 45 of Set 12 | oneonta
# Processing Record 46 of Set 12 | swadlincote
# Processing Record 47 of Set 12 | yanam
# Processing Record 48 of Set 12 | waingapu
# Processing Record 49 of Set 12 | lethem
# Processing Record 50 of Set 12 | odienne
# Processing Record 1 of Set 13 | saint pete beach
# Processing Record 2 of Set 13 | chifeng
# Processing Record 3 of Set 13 | batemans bay
# Processing Record 4 of Set 13 | lokosovo
# Processing Record 5 of Set 13 | veraval
# Processing Record 6 of Set 13 | cayhagan
# Processing Record 7 of Set 13 | kavaratti
# Processing Record 8 of Set 13 | mandalgovi
# Processing Record 9 of Set 13 | izhma
# Processing Record 10 of Set 13 | benghazi
# Processing Record 11 of Set 13 | adrian
# Processing Record 12 of Set 13 | tripoli
# Processing Record 13 of Set 13 | klyuchi
# Processing Record 14 of Set 13 | buala
# Processing Record 15 of Set 13 | hauterive
# Processing Record 16 of Set 13 | marathon
# Processing Record 17 of Set 13 | cruden bay
# City not found. Skipping...
# Processing Record 18 of Set 13 | mahajanga
# Processing Record 19 of Set 13 | astana
# Processing Record 20 of Set 13 | gasa
# Processing Record 21 of Set 13 | rondonopolis
# Processing Record 22 of Set 13 | mackay
# Processing Record 23 of Set 13 | malumfashi
# Processing Record 24 of Set 13 | porto tolle
# Processing Record 25 of Set 13 | port jervis
# Processing Record 26 of Set 13 | yangliuqing
# Processing Record 27 of Set 13 | luis correia
# Processing Record 28 of Set 13 | alpinopolis
# Processing Record 29 of Set 13 | kitob
# Processing Record 30 of Set 13 | belyy yar
# Processing Record 31 of Set 13 | souris
# Processing Record 32 of Set 13 | wa
# City not found. Skipping...
# Processing Record 33 of Set 13 | alugan
# Processing Record 34 of Set 13 | mbanza-ngungu
# Processing Record 35 of Set 13 | yongan
# Processing Record 36 of Set 13 | ipswich
# Processing Record 37 of Set 13 | naftah
# City not found. Skipping...
# Processing Record 38 of Set 13 | qeshm
# Processing Record 39 of Set 13 | kibi
# Processing Record 40 of Set 13 | luganville
# Processing Record 41 of Set 13 | peruibe
# Processing Record 42 of Set 13 | mahaicony
# City not found. Skipping...
# Processing Record 43 of Set 13 | dakar
# Processing Record 44 of Set 13 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 45 of Set 13 | san policarpo
# Processing Record 46 of Set 13 | vila
# Processing Record 47 of Set 13 | kommunar
# Processing Record 48 of Set 13 | sayyan
# Processing Record 49 of Set 13 | vikhorevka
# Processing Record 50 of Set 13 | verkh-usugli
# Processing Record 1 of Set 14 | tonj
# Processing Record 2 of Set 14 | bievre
# Processing Record 3 of Set 14 | brewster
# Processing Record 4 of Set 14 | kwinana
# Processing Record 5 of Set 14 | tashtyp
# Processing Record 6 of Set 14 | northam
# Processing Record 7 of Set 14 | ischia
# Processing Record 8 of Set 14 | lanivtsi
# Processing Record 9 of Set 14 | punta alta
# Processing Record 10 of Set 14 | chegdomyn
# Processing Record 11 of Set 14 | maghama
# City not found. Skipping...
# Processing Record 12 of Set 14 | minab
# Processing Record 13 of Set 14 | villa carlos paz
# Processing Record 14 of Set 14 | warkworth
# Processing Record 15 of Set 14 | tura
# Processing Record 16 of Set 14 | knysna
# Processing Record 17 of Set 14 | aldan
# Processing Record 18 of Set 14 | bonthe
# Processing Record 19 of Set 14 | arlit
# Processing Record 20 of Set 14 | los llanos de aridane
# Processing Record 21 of Set 14 | wenling
# Processing Record 22 of Set 14 | port blair
# Processing Record 23 of Set 14 | majene
# Processing Record 24 of Set 14 | duiwelskloof
# Processing Record 25 of Set 14 | yenotayevka
# Processing Record 26 of Set 14 | gualaquiza
# Processing Record 27 of Set 14 | sechura
# Processing Record 28 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 29 of Set 14 | grand baie
# Processing Record 30 of Set 14 | penzance
# Processing Record 31 of Set 14 | mancio lima
# Processing Record 32 of Set 14 | chabahar
# Processing Record 33 of Set 14 | chara
# Processing Record 34 of Set 14 | necochea
# Processing Record 35 of Set 14 | chistogorskiy
# Processing Record 36 of Set 14 | bucerias
# Processing Record 37 of Set 14 | ambalavao
# Processing Record 38 of Set 14 | victor harbor
# Processing Record 39 of Set 14 | hambantota
# Processing Record 40 of Set 14 | vozhega
# Processing Record 41 of Set 14 | kropotkin
# Processing Record 42 of Set 14 | at-bashi
# Processing Record 43 of Set 14 | ondjiva
# Processing Record 44 of Set 14 | karatuzskoye
# Processing Record 45 of Set 14 | ayan
# Processing Record 46 of Set 14 | paranavai
# Processing Record 47 of Set 14 | buenaventura
# Processing Record 48 of Set 14 | rafaela
# Processing Record 49 of Set 14 | angoche
# Processing Record 50 of Set 14 | maxixe
# Processing Record 1 of Set 15 | rolim de moura
# City not found. Skipping...
# Processing Record 2 of Set 15 | harper
# Processing Record 3 of Set 15 | tabory
# Processing Record 4 of Set 15 | korla
# Processing Record 5 of Set 15 | muisne
# Processing Record 6 of Set 15 | mao
# Processing Record 7 of Set 15 | bafoulabe
# Processing Record 8 of Set 15 | evensk
# Processing Record 9 of Set 15 | khed brahma
# Processing Record 10 of Set 15 | rieti
# Processing Record 11 of Set 15 | katsiveli
# City not found. Skipping...
# Processing Record 12 of Set 15 | weligama
# Processing Record 13 of Set 15 | comodoro rivadavia
# Processing Record 14 of Set 15 | bosaso
# Processing Record 15 of Set 15 | magui
# City not found. Skipping...
# Processing Record 16 of Set 15 | prieska
# Processing Record 17 of Set 15 | acarau
# Processing Record 18 of Set 15 | poum
# Processing Record 19 of Set 15 | bressanone
# Processing Record 20 of Set 15 | talcahuano
# Processing Record 21 of Set 15 | chama
# Processing Record 22 of Set 15 | reoti
# Processing Record 23 of Set 15 | bullhead city
# Processing Record 24 of Set 15 | garh maharaja
# Processing Record 25 of Set 15 | kuva
# City not found. Skipping...
# Processing Record 26 of Set 15 | dessalines
# Processing Record 27 of Set 15 | ambon
# Processing Record 28 of Set 15 | menongue
# Processing Record 29 of Set 15 | biak
# Processing Record 30 of Set 15 | narodychi
# Processing Record 31 of Set 15 | iwanai
# Processing Record 32 of Set 15 | oussouye
# Processing Record 33 of Set 15 | labytnangi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
import pandas as pd
# Add the data to a new DataFrame.
weather_data_df = pd.DataFrame(weather_data)
weather_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Kavieng      PG  -2.5744  150.7967     82.42        81          99
# 1    Whitehorse      CA  60.7161 -135.0538     84.02        31          48
# 2          Atar      MR  20.5169  -13.0499     99.55        16          98
# 3       Rikitea      PF -23.1203 -134.9692     76.19        73           5
# 4      Lorengau      PG  -2.0226  147.2712     81.73        78         100
# 5     Busselton      AU -33.6500  115.3333     50.50        66          76
# 6     Jamestown      US  42.0970  -79.2353     78.03        81         100
# 7       Itarema      BR  -2.9248  -39.9167     77.27        69          99
# 8       Ushuaia      AR -54.8000  -68.3000     25.29        94          96
# 9  Punta Arenas      CL -53.1500  -70.9167     32.25        84         100
#
#    Wind Speed   Current Description
# 0       14.67       overcast clouds
# 1        5.99      scattered clouds
# 2        3.42       overcast clouds
# 3       18.23             clear sky
# 4        6.17  heavy intensity rain
# 5        9.13         broken clouds
# 6       10.36       overcast clouds
# 7        8.46       overcast clouds
# 8        1.54       overcast clouds
# 9        1.83       overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
weather_data_df = weather_data_df[new_column_order]
weather_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Kavieng      PG  -2.5744  150.7967     82.42        81          99
# 1    Whitehorse      CA  60.7161 -135.0538     84.02        31          48
# 2          Atar      MR  20.5169  -13.0499     99.55        16          98
# 3       Rikitea      PF -23.1203 -134.9692     76.19        73           5
# 4      Lorengau      PG  -2.0226  147.2712     81.73        78         100
# 5     Busselton      AU -33.6500  115.3333     50.50        66          76
# 6     Jamestown      US  42.0970  -79.2353     78.03        81         100
# 7       Itarema      BR  -2.9248  -39.9167     77.27        69          99
# 8       Ushuaia      AR -54.8000  -68.3000     25.29        94          96
# 9  Punta Arenas      CL -53.1500  -70.9167     32.25        84         100
#
#    Wind Speed   Current Description
# 0       14.67       overcast clouds
# 1        5.99      scattered clouds
# 2        3.42       overcast clouds
# 3       18.23             clear sky
# 4        6.17  heavy intensity rain
# 5        9.13         broken clouds
# 6       10.36       overcast clouds
# 7        8.46       overcast clouds
# 8        1.54       overcast clouds
# 9        1.83       overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
weather_data_df.to_csv(output_data_file, index_label="City_ID")
